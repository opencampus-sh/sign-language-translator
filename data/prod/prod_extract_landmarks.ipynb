# %% [markdown]
# # Extracting landmarks from the video

# %% [markdown]
# ffmpeg is requiered:
# sudo apt install ffmpeg

# %%
# !pip -q install mediapipe opencv-python moviepy
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.6/35.6 MB 15.2 MB/s eta 0:00:00

# %%
import os
import requests
from moviepy.editor import VideoFileClip

# URL of the video
video_url = "https://media.tagesschau.de/video/2024/1105/TV-20241105-2024-1400.webxxl.h264.mp4"

# Send a GET request to the URL
response = requests.get(video_url, stream=True)

if response.status_code == 200:
    # Try to extract the filename from the Content-Disposition header
    filename = None
    if 'Content-Disposition' in response.headers:
        content_disposition = response.headers['Content-Disposition']
        if 'filename=' in content_disposition:
            filename = content_disposition.split('filename=')[1].strip('\"')

    # Fallback to extracting the filename from the URL if header is not present
    if not filename:
        filename = os.path.basename(video_url)

    # Save the video file
    video_filepath = filename
    with open(video_filepath, "wb") as file:
        for chunk in response.iter_content(chunk_size=1024):
            if chunk:
                file.write(chunk)
    print(f"Video downloaded successfully as {video_filepath}")

    # Extract audio and save as MP3
    audio_filename = os.path.splitext(filename)[0] + ".mp3"  # Change extension to .mp3
    video_clip = VideoFileClip(video_filepath)
    audio_clip = video_clip.audio
    audio_clip.write_audiofile(audio_filename)
    audio_clip.close()
    video_clip.close()

    print(f"Audio extracted and saved as {audio_filename}")
else:
    print(f"Failed to download video. Status code: {response.status_code}")
# Out:
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/sliders.py:61: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if event.key is 'enter':
# Video downloaded successfully as TV-20241105-2024-1400.webxxl.h264.mp4
# MoviePy - Writing audio in TV-20241105-2024-1400.webxxl.h264.mp3
# MoviePy - Done.
# Audio extracted and saved as TV-20241105-2024-1400.webxxl.h264.mp3

# %%
import cv2
import mediapipe as mp

# %% [markdown]
# Google's MediaPipe Hands solution outputs a set of 21 3D hand landmarks for each detected hand in the input image or video. These landmarks represent key points on the hand, such as the tips of fingers, joints, and the wrist. Each landmark is identified by its index and provides three key pieces of data:
#
# - x: The normalized x-coordinate of the landmark, relative to the width of the input image. The value is in the range [0, 1].
# - y: The normalized y-coordinate of the landmark, relative to the height of the input image. The value is in the range [0, 1].
# - z: The normalized z-coordinate of the landmark, which indicates the depth of the landmark relative to the wrist. A smaller value means the landmark is closer to the camera.

# %%
import cv2
import mediapipe as mp
import json
from mediapipe.framework.formats import landmark_pb2  # Import added

def extract_holistic_landmarks(input_video_path, landmarks_output_path):
    # Initialize VideoCapture
    cap = cv2.VideoCapture(input_video_path)
    if not cap.isOpened():
        print(f"Error opening video file {input_video_path}")
        return

    # Get video properties
    frame_count = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))

    # Calculate the starting x-coordinate for the right half
    right_half_width = width // 2
    start_x = width - right_half_width  # Start from right half of the width

    # Initialize the MediaPipe Holistic solution
    mp_holistic = mp.solutions.holistic

    # Open the landmarks output file
    try:
        f_landmarks = open(landmarks_output_path, 'w')
        f_landmarks.write('[')  # Start of JSON array
    except Exception as e:
        print(f"Error opening landmarks file {landmarks_output_path}: {e}")
        return

    # Define a helper function to extract x, y, z from a landmark list
    def get_landmarks(landmark_list):
        return [
            {"x": lm.x, "y": lm.y, "z": lm.z}
            for lm in landmark_list.landmark
        ] if landmark_list else []

    with mp_holistic.Holistic(
        static_image_mode=False,
        model_complexity=1,
        smooth_landmarks=True,
        enable_segmentation=False,
        refine_face_landmarks=False,
        min_detection_confidence=0.5,
        min_tracking_confidence=0.5
    ) as holistic:
        frame_idx = 0
        while cap.isOpened():
            ret, frame_bgr = cap.read()
            if not ret:
                break

            # --- Process Only the right half of the Frame ---
            # Crop the right half of the frame
            right_half_frame = frame_bgr[:, start_x:width]

            # Convert the cropped BGR image to RGB
            image = cv2.cvtColor(right_half_frame, cv2.COLOR_BGR2RGB)
            image.flags.writeable = False

            # Process the image with MediaPipe Holistic
            results = holistic.process(image)

            # Prepare data structure for the current frame
            frame_landmarks = {
                "frame": frame_idx,
                "pose_landmarks": [],       # Body pose
                "face_landmarks": [],       # Face
                "left_hand_landmarks": [],  # Left hand
                "right_hand_landmarks": []  # Right hand
            }

            # Pose landmarks (if any)
            if results.pose_landmarks:
                frame_landmarks["pose_landmarks"] = get_landmarks(results.pose_landmarks)

            # Face landmarks (if any)
            if results.face_landmarks:
                frame_landmarks["face_landmarks"] = get_landmarks(results.face_landmarks)

            # Left hand landmarks (if any)
            if results.left_hand_landmarks:
                frame_landmarks["left_hand_landmarks"] = get_landmarks(results.left_hand_landmarks)

            # Right hand landmarks (if any)
            if results.right_hand_landmarks:
                frame_landmarks["right_hand_landmarks"] = get_landmarks(results.right_hand_landmarks)

            # Write the current frame's landmarks to the JSON file
            json.dump(frame_landmarks, f_landmarks)
            if frame_idx < frame_count - 1:
                f_landmarks.write(',\n')  # Add comma except after the last item

            # Increment frame index
            frame_idx += 1

            # Optional: Display progress
            if frame_idx % 100 == 0:
                print(f"Processed {frame_idx}/{frame_count} frames.")

        # Close the JSON array
        f_landmarks.write(']')
        f_landmarks.close()

    # Release resources
    cap.release()

    print(f"Holistic landmarks have been saved to {landmarks_output_path}")

# %%
# List of input video file paths
input_videos = [
    'TV-20241105-2024-1400.webxxl.h264.mp4'
    # Add more video file paths as needed
]

# Directory to save output videos and landmarks
output_dir = 'processed_videos'

# Ensure the output directory exists
import os
import time

os.makedirs(output_dir, exist_ok=True)

# Process each video
for input_video in input_videos:
    # Generate output file paths
    base_name = os.path.splitext(os.path.basename(input_video))[0]
    landmarks_output = os.path.join(output_dir, f"{base_name}_landmarks.json")

    # Start timer
    start_time = time.time()

    # Call the process_video function
    print(f"Processing {input_video}...")
    extract_landmarks(input_video, landmarks_output)
    print(f"Finished processing {input_video}")

    # Stop timer
    end_time = time.time()

    # Calculate and print elapsed time
    elapsed_time = end_time - start_time
    print(f"Time taken for {input_video}: {elapsed_time:.2f} seconds\n")
# Out:
# Processing TV-20241105-2024-1400.webxxl.h264.mp4...
# Processed 100/24944 frames.
# Processed 200/24944 frames.
# Processed 300/24944 frames.
# Processed 400/24944 frames.
# Processed 500/24944 frames.
# Processed 600/24944 frames.
# Processed 700/24944 frames.
# Processed 800/24944 frames.
# Processed 900/24944 frames.
# Processed 1000/24944 frames.
# Processed 1100/24944 frames.
# Processed 1200/24944 frames.
# Processed 1300/24944 frames.
# Processed 1400/24944 frames.
# Processed 1500/24944 frames.
# Processed 1600/24944 frames.
# Processed 1700/24944 frames.
# Processed 1800/24944 frames.
# Processed 1900/24944 frames.
# Processed 2000/24944 frames.
# Processed 2100/24944 frames.
# Processed 2200/24944 frames.
# Processed 2300/24944 frames.
# Processed 2400/24944 frames.
# Processed 2500/24944 frames.
# Processed 2600/24944 frames.
# Processed 2700/24944 frames.
# Processed 2800/24944 frames.
# Processed 2900/24944 frames.
# Processed 3000/24944 frames.
# Processed 3100/24944 frames.
# Processed 3200/24944 frames.
# Processed 3300/24944 frames.
# Processed 3400/24944 frames.
# Processed 3500/24944 frames.
# Processed 3600/24944 frames.
# Processed 3700/24944 frames.
# Processed 3800/24944 frames.
# Processed 3900/24944 frames.
# Processed 4000/24944 frames.
# Processed 4100/24944 frames.
# Processed 4200/24944 frames.
# Processed 4300/24944 frames.
# Processed 4400/24944 frames.
# Processed 4500/24944 frames.
# Processed 4600/24944 frames.
# Processed 4700/24944 frames.
# Processed 4800/24944 frames.
# Processed 4900/24944 frames.
# Processed 5000/24944 frames.
# Processed 5100/24944 frames.
# Processed 5200/24944 frames.
# Processed 5300/24944 frames.
# Processed 5400/24944 frames.
# Processed 5500/24944 frames.
# Processed 5600/24944 frames.
# Processed 5700/24944 frames.
# Processed 5800/24944 frames.
# Processed 5900/24944 frames.
# Processed 6000/24944 frames.
# Processed 6100/24944 frames.
# Processed 6200/24944 frames.
# Processed 6300/24944 frames.
# Processed 6400/24944 frames.
# Processed 6500/24944 frames.
# Processed 6600/24944 frames.
# Processed 6700/24944 frames.
# Processed 6800/24944 frames.
# Processed 6900/24944 frames.
# Processed 7000/24944 frames.
# Processed 7100/24944 frames.
# Processed 7200/24944 frames.
# Processed 7300/24944 frames.
# Processed 7400/24944 frames.
# Processed 7500/24944 frames.
# Processed 7600/24944 frames.
# Processed 7700/24944 frames.
# Processed 7800/24944 frames.
# Processed 7900/24944 frames.
# Processed 8000/24944 frames.
# Processed 8100/24944 frames.
# Processed 8200/24944 frames.
# Processed 8300/24944 frames.
# Processed 8400/24944 frames.
# Processed 8500/24944 frames.
# Processed 8600/24944 frames.
# Processed 8700/24944 frames.
# Processed 8800/24944 frames.
# Processed 8900/24944 frames.
# Processed 9000/24944 frames.
# Processed 9100/24944 frames.
# Processed 9200/24944 frames.
# Processed 9300/24944 frames.
# Processed 9400/24944 frames.
# Processed 9500/24944 frames.
# Processed 9600/24944 frames.
# Processed 9700/24944 frames.
# Processed 9800/24944 frames.
# Processed 9900/24944 frames.
# Processed 10000/24944 frames.
# Processed 10100/24944 frames.
# Processed 10200/24944 frames.
# Processed 10300/24944 frames.
# Processed 10400/24944 frames.
# Processed 10500/24944 frames.
# Processed 10600/24944 frames.
# Processed 10700/24944 frames.
# Processed 10800/24944 frames.
# Processed 10900/24944 frames.
# Processed 11000/24944 frames.
# Processed 11100/24944 frames.
# Processed 11200/24944 frames.
# Processed 11300/24944 frames.
# Processed 11400/24944 frames.
# Processed 11500/24944 frames.
# Processed 11600/24944 frames.
# Processed 11700/24944 frames.
# Processed 11800/24944 frames.
# Processed 11900/24944 frames.
# Processed 12000/24944 frames.
# Processed 12100/24944 frames.
# Processed 12200/24944 frames.
# Processed 12300/24944 frames.
# Processed 12400/24944 frames.
# Processed 12500/24944 frames.
# Processed 12600/24944 frames.
# Processed 12700/24944 frames.
# Processed 12800/24944 frames.
# Processed 12900/24944 frames.
# Processed 13000/24944 frames.
# Processed 13100/24944 frames.
# Processed 13200/24944 frames.
# Processed 13300/24944 frames.
# Processed 13400/24944 frames.
# Processed 13500/24944 frames.
# Processed 13600/24944 frames.
# Processed 13700/24944 frames.
# Processed 13800/24944 frames.
# Processed 13900/24944 frames.
# Processed 14000/24944 frames.
# Processed 14100/24944 frames.
# Processed 14200/24944 frames.
# Processed 14300/24944 frames.
# Processed 14400/24944 frames.
# Processed 14500/24944 frames.
# Processed 14600/24944 frames.
# Processed 14700/24944 frames.
# Processed 14800/24944 frames.
# Processed 14900/24944 frames.
# Processed 15000/24944 frames.
# Processed 15100/24944 frames.
# Processed 15200/24944 frames.
# Processed 15300/24944 frames.
# Processed 15400/24944 frames.
# Processed 15500/24944 frames.
# Processed 15600/24944 frames.
# Processed 15700/24944 frames.
# Processed 15800/24944 frames.
# Processed 15900/24944 frames.
# Processed 16000/24944 frames.
# Processed 16100/24944 frames.
# Processed 16200/24944 frames.
# Processed 16300/24944 frames.
# Processed 16400/24944 frames.
# Processed 16500/24944 frames.
# Processed 16600/24944 frames.
# Processed 16700/24944 frames.
# Processed 16800/24944 frames.
# Processed 16900/24944 frames.
# Processed 17000/24944 frames.
# Processed 17100/24944 frames.
# Processed 17200/24944 frames.
# Processed 17300/24944 frames.
# Processed 17400/24944 frames.
# Processed 17500/24944 frames.
# Processed 17600/24944 frames.
# Processed 17700/24944 frames.
# Processed 17800/24944 frames.
# Processed 17900/24944 frames.
# Processed 18000/24944 frames.
# Processed 18100/24944 frames.
# Processed 18200/24944 frames.
# Processed 18300/24944 frames.
# Processed 18400/24944 frames.
# Processed 18500/24944 frames.
# Processed 18600/24944 frames.
# Processed 18700/24944 frames.
# Processed 18800/24944 frames.
# Processed 18900/24944 frames.
# Processed 19000/24944 frames.
# Processed 19100/24944 frames.
# Processed 19200/24944 frames.
# Processed 19300/24944 frames.
# Processed 19400/24944 frames.
# Processed 19500/24944 frames.
# Processed 19600/24944 frames.
# Processed 19700/24944 frames.
# Processed 19800/24944 frames.
# Processed 19900/24944 frames.
# Processed 20000/24944 frames.
# Processed 20100/24944 frames.
# Processed 20200/24944 frames.
# Processed 20300/24944 frames.
# Processed 20400/24944 frames.
# Processed 20500/24944 frames.
# Processed 20600/24944 frames.
# Processed 20700/24944 frames.
# Processed 20800/24944 frames.
# Processed 20900/24944 frames.
# Processed 21000/24944 frames.
# Processed 21100/24944 frames.
# Processed 21200/24944 frames.
# Processed 21300/24944 frames.
# Processed 21400/24944 frames.
# Processed 21500/24944 frames.
# Processed 21600/24944 frames.
# Processed 21700/24944 frames.
# Processed 21800/24944 frames.
# Processed 21900/24944 frames.
# Processed 22000/24944 frames.
# Processed 22100/24944 frames.
# Processed 22200/24944 frames.
# Processed 22300/24944 frames.
# Processed 22400/24944 frames.
# Processed 22500/24944 frames.
# Processed 22600/24944 frames.
# Processed 22700/24944 frames.
# Processed 22800/24944 frames.
# Processed 22900/24944 frames.
# Processed 23000/24944 frames.
# Processed 23100/24944 frames.
# Processed 23200/24944 frames.
# Processed 23300/24944 frames.
# Processed 23400/24944 frames.
# Processed 23500/24944 frames.
# Processed 23600/24944 frames.
# Processed 23700/24944 frames.
# Processed 23800/24944 frames.
# Processed 23900/24944 frames.
# Processed 24000/24944 frames.
# Processed 24100/24944 frames.
# Processed 24200/24944 frames.
# Processed 24300/24944 frames.
# Processed 24400/24944 frames.
# Processed 24500/24944 frames.
# Processed 24600/24944 frames.
# Processed 24700/24944 frames.
# Processed 24800/24944 frames.
# Processed 24900/24944 frames.
# Landmarks have been saved to processed_videos/TV-20241105-2024-1400.webxxl.h264_landmarks.json
# Finished processing TV-20241105-2024-1400.webxxl.h264.mp4
# Time taken for TV-20241105-2024-1400.webxxl.h264.mp4: 1334.42 seconds
